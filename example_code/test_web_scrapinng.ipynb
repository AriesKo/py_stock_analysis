# %%
import pandas as pd

# %%
krx_list = pd.read_html(r'C:\Users\sangi\dev\py_stock_data_analysis\Data\상장법인목록.xlsx')
# krx_list = pd.read_excel(r'C:\Users\sangi\dev\py_stock_data_analysis\Data\상장법인목록.xlsx')
krx_list[0].종목코드 = krx_list[0].종목코드.map('{:06d}'.format)
krx_list[0]
# Out:
#                회사명    종목코드                   업종  \
# 0         차이커뮤니케이션  351870                  광고업
# 1     한화인더스트리얼솔루션즈  489790               기타 금융업
# 2         KB제30호스팩  486630           금융 지원 서비스업
# 3          아이언디바이스  464500              반도체 제조업
# 4       미래에셋비전스팩7호  482680           금융 지원 서비스업
# ...            ...     ...                  ...
# 2713          유한양행  000100              의약품 제조업
# 2714        CJ대한통운  000120            도로 화물 운송업
# 2715            경방  000050               종합 소매업
# 2716         유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업
# 2717      한진중공업홀딩스  003480    연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                                          광고대행, 광고물 작성  2024-09-27  12월
# 1                                               비금융지주회사  2024-09-27  12월
# 2                                                기업인수합병  2024-09-25  12월
# 3                                  스마트폰용 오디오 앰프 반도체 Soc  2024-09-23  12월
# ...

# %%
krx_list = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13',encoding='cp949')[0]
# krx_list = pd.read_excel(r'C:\Users\sangi\dev\py_stock_data_analysis\Data\상장법인목록.xlsx')
krx_list.종목코드 = krx_list.종목코드.map('{:06d}'.format)
krx_list
# Out:
# c:\Users\sangi\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\__init__.py:228: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
#             회사명    종목코드                        업종  \
# 0        BGF리테일  282330                    종합 소매업
# 1         DRB동일  004840                  고무제품 제조업
# 2            E1  017940                 기타 전문 도매업
# 3     HDC현대산업개발  294870                    건물 건설업
# 4     HD현대마린솔루션  443060  건축기술, 엔지니어링 및 관련 기술 서비스업
# ...         ...     ...                       ...
# 2714       이앤에치  341310               기타 섬유제품 제조업
# 2715        큐러블  086460           자연과학 및 공학 연구개발업
# 2716        타스컴  336040                의료용 기기 제조업
# 2717        테크엔  308700             전구 및 조명장치 제조업
# 2718    펨토바이오메드  327610                의료용 기기 제조업
#
# ...
